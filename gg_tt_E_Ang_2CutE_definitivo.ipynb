# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import timeit
import seaborn as sns

# %%
theta = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Angles.txt", delimiter=" ", unpack='true')

E = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Energy.txt", delimiter=" ", unpack='true')

M = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/MatrElem.txt", delimiter=" ", unpack='true')

t = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Time.txt", delimiter=" ", unpack='true')


max(theta)
# Out:
# 3.1411891489542554

# %%
angle_cut1 = 10./180.* math.pi
angle_cut2 = 170./180.*math.pi
Ecut = 0

# %%
ind = []
dim = M.size
for i in range(dim):
    if E[i] < 200 or theta[i] < angle_cut1 or theta[i] > angle_cut2:
        ind.append(i)
    if i%10000 == 0:
        print(i/10000, "/",dim/10000)
# Out:
# 0.0 / 1000.0
# 1.0 / 1000.0
# 2.0 / 1000.0
# 3.0 / 1000.0
# 4.0 / 1000.0
# 5.0 / 1000.0
# 6.0 / 1000.0
# 7.0 / 1000.0
# 8.0 / 1000.0
# 9.0 / 1000.0
# 10.0 / 1000.0
# 11.0 / 1000.0
# 12.0 / 1000.0
# 13.0 / 1000.0
# 14.0 / 1000.0
# 15.0 / 1000.0
# 16.0 / 1000.0
# 17.0 / 1000.0
# 18.0 / 1000.0
# 19.0 / 1000.0
# 20.0 / 1000.0
# 21.0 / 1000.0
# 22.0 / 1000.0
# 23.0 / 1000.0
# 24.0 / 1000.0
# 25.0 / 1000.0
# 26.0 / 1000.0
# 27.0 / 1000.0
# 28.0 / 1000.0
# 29.0 / 1000.0
# 30.0 / 1000.0
# 31.0 / 1000.0
# 32.0 / 1000.0
# 33.0 / 1000.0
# 34.0 / 1000.0
# 35.0 / 1000.0
# 36.0 / 1000.0
# 37.0 / 1000.0
# 38.0 / 1000.0
# 39.0 / 1000.0
# 40.0 / 1000.0
# 41.0 / 1000.0
# 42.0 / 1000.0
# 43.0 / 1000.0
# 44.0 / 1000.0
# 45.0 / 1000.0
# 46.0 / 1000.0
# 47.0 / 1000.0
# 48.0 / 1000.0
# 49.0 / 1000.0
# 50.0 / 1000.0
# 51.0 / 1000.0
# 52.0 / 1000.0
# 53.0 / 1000.0
# 54.0 / 1000.0
# 55.0 / 1000.0
# 56.0 / 1000.0
# 57.0 / 1000.0
# 58.0 / 1000.0
# 59.0 / 1000.0
# 60.0 / 1000.0
# 61.0 / 1000.0
# 62.0 / 1000.0
# 63.0 / 1000.0
# 64.0 / 1000.0
# 65.0 / 1000.0
# 66.0 / 1000.0
# 67.0 / 1000.0
# 68.0 / 1000.0
# 69.0 / 1000.0
# 70.0 / 1000.0
# 71.0 / 1000.0
# 72.0 / 1000.0
# 73.0 / 1000.0
# 74.0 / 1000.0
# 75.0 / 1000.0
# 76.0 / 1000.0
# 77.0 / 1000.0
# 78.0 / 1000.0
# 79.0 / 1000.0
# 80.0 / 1000.0
# 81.0 / 1000.0
# 82.0 / 1000.0
# 83.0 / 1000.0
# 84.0 / 1000.0
# 85.0 / 1000.0
# 86.0 / 1000.0
# 87.0 / 1000.0
# 88.0 / 1000.0
# 89.0 / 1000.0
# 90.0 / 1000.0
# 91.0 / 1000.0
# 92.0 / 1000.0
# 93.0 / 1000.0
# 94.0 / 1000.0
# 95.0 / 1000.0
# 96.0 / 1000.0
# 97.0 / 1000.0
# 98.0 / 1000.0
# 99.0 / 1000.0
# 100.0 / 1000.0
# 101.0 / 1000.0
# 102.0 / 1000.0
# 103.0 / 1000.0
# 104.0 / 1000.0
# 105.0 / 1000.0
# 106.0 / 1000.0
# 107.0 / 1000.0
# 108.0 / 1000.0
# 109.0 / 1000.0
# 110.0 / 1000.0
# 111.0 / 1000.0
# 112.0 / 1000.0
# 113.0 / 1000.0
# 114.0 / 1000.0
# 115.0 / 1000.0
# 116.0 / 1000.0
# 117.0 / 1000.0
# 118.0 / 1000.0
# 119.0 / 1000.0
# 120.0 / 1000.0
# 121.0 / 1000.0
# 122.0 / 1000.0
# 123.0 / 1000.0
# 124.0 / 1000.0
# 125.0 / 1000.0
# 126.0 / 1000.0
# 127.0 / 1000.0
# 128.0 / 1000.0
# 129.0 / 1000.0
# 130.0 / 1000.0
# 131.0 / 1000.0
# 132.0 / 1000.0
# 133.0 / 1000.0
# 134.0 / 1000.0
# 135.0 / 1000.0
# 136.0 / 1000.0
# 137.0 / 1000.0
# 138.0 / 1000.0
# 139.0 / 1000.0
# 140.0 / 1000.0
# 141.0 / 1000.0
# 142.0 / 1000.0
# 143.0 / 1000.0
# 144.0 / 1000.0
# 145.0 / 1000.0
# 146.0 / 1000.0
# 147.0 / 1000.0
# 148.0 / 1000.0
# 149.0 / 1000.0
# 150.0 / 1000.0
# 151.0 / 1000.0
# 152.0 / 1000.0
# 153.0 / 1000.0
# 154.0 / 1000.0
# 155.0 / 1000.0
# 156.0 / 1000.0
# 157.0 / 1000.0
# 158.0 / 1000.0
# 159.0 / 1000.0
# 160.0 / 1000.0
# 161.0 / 1000.0
# 162.0 / 1000.0
# 163.0 / 1000.0
# 164.0 / 1000.0
# 165.0 / 1000.0
# 166.0 / 1000.0
# 167.0 / 1000.0
# 168.0 / 1000.0
# 169.0 / 1000.0
# 170.0 / 1000.0
# 171.0 / 1000.0
# 172.0 / 1000.0
# 173.0 / 1000.0
# 174.0 / 1000.0
# 175.0 / 1000.0
# 176.0 / 1000.0
# 177.0 / 1000.0
# 178.0 / 1000.0
# 179.0 / 1000.0
# 180.0 / 1000.0
# 181.0 / 1000.0
# 182.0 / 1000.0
# 183.0 / 1000.0
# 184.0 / 1000.0
# 185.0 / 1000.0
# 186.0 / 1000.0
# 187.0 / 1000.0
# 188.0 / 1000.0
# 189.0 / 1000.0
# 190.0 / 1000.0
# 191.0 / 1000.0
# 192.0 / 1000.0
# 193.0 / 1000.0
# 194.0 / 1000.0
# 195.0 / 1000.0
# 196.0 / 1000.0
# 197.0 / 1000.0
# 198.0 / 1000.0
# 199.0 / 1000.0
# 200.0 / 1000.0
# 201.0 / 1000.0
# 202.0 / 1000.0
# 203.0 / 1000.0
# 204.0 / 1000.0
# 205.0 / 1000.0
# 206.0 / 1000.0
# 207.0 / 1000.0
# 208.0 / 1000.0
# 209.0 / 1000.0
# 210.0 / 1000.0
# 211.0 / 1000.0
# 212.0 / 1000.0
# 213.0 / 1000.0
# 214.0 / 1000.0
# 215.0 / 1000.0
# 216.0 / 1000.0
# 217.0 / 1000.0
# 218.0 / 1000.0
# 219.0 / 1000.0
# 220.0 / 1000.0
# 221.0 / 1000.0
# 222.0 / 1000.0
# 223.0 / 1000.0
# 224.0 / 1000.0
# 225.0 / 1000.0
# 226.0 / 1000.0
# 227.0 / 1000.0
# 228.0 / 1000.0
# 229.0 / 1000.0
# 230.0 / 1000.0
# 231.0 / 1000.0
# 232.0 / 1000.0
# 233.0 / 1000.0
# 234.0 / 1000.0
# 235.0 / 1000.0
# 236.0 / 1000.0
# 237.0 / 1000.0
# 238.0 / 1000.0
# 239.0 / 1000.0
# 240.0 / 1000.0
# 241.0 / 1000.0
# 242.0 / 1000.0
# 243.0 / 1000.0
# 244.0 / 1000.0
# 245.0 / 1000.0
# 246.0 / 1000.0
# 247.0 / 1000.0
# 248.0 / 1000.0
# 249.0 / 1000.0
# 250.0 / 1000.0
# 251.0 / 1000.0
# 252.0 / 1000.0
# 253.0 / 1000.0
# 254.0 / 1000.0
# 255.0 / 1000.0
# 256.0 / 1000.0
# 257.0 / 1000.0
# 258.0 / 1000.0
# 259.0 / 1000.0
# 260.0 / 1000.0
# 261.0 / 1000.0
# 262.0 / 1000.0
# 263.0 / 1000.0
# 264.0 / 1000.0
# 265.0 / 1000.0
# 266.0 / 1000.0
# 267.0 / 1000.0
# 268.0 / 1000.0
# 269.0 / 1000.0
# 270.0 / 1000.0
# 271.0 / 1000.0
# 272.0 / 1000.0
# 273.0 / 1000.0
# 274.0 / 1000.0
# 275.0 / 1000.0
# 276.0 / 1000.0
# 277.0 / 1000.0
# 278.0 / 1000.0
# 279.0 / 1000.0
# 280.0 / 1000.0
# 281.0 / 1000.0
# 282.0 / 1000.0
# 283.0 / 1000.0
# 284.0 / 1000.0
# 285.0 / 1000.0
# 286.0 / 1000.0
# 287.0 / 1000.0
# 288.0 / 1000.0
# 289.0 / 1000.0
# 290.0 / 1000.0
# 291.0 / 1000.0
# 292.0 / 1000.0
# 293.0 / 1000.0
# 294.0 / 1000.0
# 295.0 / 1000.0
# 296.0 / 1000.0
# 297.0 / 1000.0
# 298.0 / 1000.0
# 299.0 / 1000.0
# 300.0 / 1000.0
# 301.0 / 1000.0
# 302.0 / 1000.0
# 303.0 / 1000.0
# 304.0 / 1000.0
# 305.0 / 1000.0
# 306.0 / 1000.0
# 307.0 / 1000.0
# 308.0 / 1000.0
# 309.0 / 1000.0
# 310.0 / 1000.0
# 311.0 / 1000.0
# 312.0 / 1000.0
# 313.0 / 1000.0
# 314.0 / 1000.0
# 315.0 / 1000.0
# 316.0 / 1000.0
# 317.0 / 1000.0
# 318.0 / 1000.0
# 319.0 / 1000.0
# 320.0 / 1000.0
# 321.0 / 1000.0
# 322.0 / 1000.0
# 323.0 / 1000.0
# 324.0 / 1000.0
# 325.0 / 1000.0
# 326.0 / 1000.0
# 327.0 / 1000.0
# 328.0 / 1000.0
# 329.0 / 1000.0
# 330.0 / 1000.0
# 331.0 / 1000.0
# 332.0 / 1000.0
# 333.0 / 1000.0
# 334.0 / 1000.0
# 335.0 / 1000.0
# 336.0 / 1000.0
# 337.0 / 1000.0
# 338.0 / 1000.0
# 339.0 / 1000.0
# 340.0 / 1000.0
# 341.0 / 1000.0
# 342.0 / 1000.0
# 343.0 / 1000.0
# 344.0 / 1000.0
# 345.0 / 1000.0
# 346.0 / 1000.0
# 347.0 / 1000.0
# 348.0 / 1000.0
# 349.0 / 1000.0
# 350.0 / 1000.0
# 351.0 / 1000.0
# 352.0 / 1000.0
# 353.0 / 1000.0
# 354.0 / 1000.0
# 355.0 / 1000.0
# 356.0 / 1000.0
# 357.0 / 1000.0
# 358.0 / 1000.0
# 359.0 / 1000.0
# 360.0 / 1000.0
# 361.0 / 1000.0
# 362.0 / 1000.0
# 363.0 / 1000.0
# 364.0 / 1000.0
# 365.0 / 1000.0
# 366.0 / 1000.0
# 367.0 / 1000.0
# 368.0 / 1000.0
# 369.0 / 1000.0
# 370.0 / 1000.0
# 371.0 / 1000.0
# 372.0 / 1000.0
# 373.0 / 1000.0
# 374.0 / 1000.0
# 375.0 / 1000.0
# 376.0 / 1000.0
# 377.0 / 1000.0
# 378.0 / 1000.0
# 379.0 / 1000.0
# 380.0 / 1000.0
# 381.0 / 1000.0
# 382.0 / 1000.0
# 383.0 / 1000.0
# 384.0 / 1000.0
# 385.0 / 1000.0
# 386.0 / 1000.0
# 387.0 / 1000.0
# 388.0 / 1000.0
# 389.0 / 1000.0
# 390.0 / 1000.0
# 391.0 / 1000.0
# 392.0 / 1000.0
# 393.0 / 1000.0
# 394.0 / 1000.0
# 395.0 / 1000.0
# 396.0 / 1000.0
# 397.0 / 1000.0
# 398.0 / 1000.0
# 399.0 / 1000.0
# 400.0 / 1000.0
# 401.0 / 1000.0
# 402.0 / 1000.0
# 403.0 / 1000.0
# 404.0 / 1000.0
# 405.0 / 1000.0
# 406.0 / 1000.0
# 407.0 / 1000.0
# 408.0 / 1000.0
# 409.0 / 1000.0
# 410.0 / 1000.0
# 411.0 / 1000.0
# 412.0 / 1000.0
# 413.0 / 1000.0
# 414.0 / 1000.0
# 415.0 / 1000.0
# 416.0 / 1000.0
# 417.0 / 1000.0
# 418.0 / 1000.0
# 419.0 / 1000.0
# 420.0 / 1000.0
# 421.0 / 1000.0
# 422.0 / 1000.0
# 423.0 / 1000.0
# 424.0 / 1000.0
# 425.0 / 1000.0
# 426.0 / 1000.0
# 427.0 / 1000.0
# 428.0 / 1000.0
# 429.0 / 1000.0
# 430.0 / 1000.0
# 431.0 / 1000.0
# 432.0 / 1000.0
# 433.0 / 1000.0
# 434.0 / 1000.0
# 435.0 / 1000.0
# 436.0 / 1000.0
# 437.0 / 1000.0
# 438.0 / 1000.0
# 439.0 / 1000.0
# 440.0 / 1000.0
# 441.0 / 1000.0
# 442.0 / 1000.0
# 443.0 / 1000.0
# 444.0 / 1000.0
# 445.0 / 1000.0
# 446.0 / 1000.0
# 447.0 / 1000.0
# 448.0 / 1000.0
# 449.0 / 1000.0
# 450.0 / 1000.0
# 451.0 / 1000.0
# 452.0 / 1000.0
# 453.0 / 1000.0
# 454.0 / 1000.0
# 455.0 / 1000.0
# 456.0 / 1000.0
# 457.0 / 1000.0
# 458.0 / 1000.0
# 459.0 / 1000.0
# 460.0 / 1000.0
# 461.0 / 1000.0
# 462.0 / 1000.0
# 463.0 / 1000.0
# 464.0 / 1000.0
# 465.0 / 1000.0
# 466.0 / 1000.0
# 467.0 / 1000.0
# 468.0 / 1000.0
# 469.0 / 1000.0
# 470.0 / 1000.0
# 471.0 / 1000.0
# 472.0 / 1000.0
# 473.0 / 1000.0
# 474.0 / 1000.0
# 475.0 / 1000.0
# 476.0 / 1000.0
# 477.0 / 1000.0
# 478.0 / 1000.0
# 479.0 / 1000.0
# 480.0 / 1000.0
# 481.0 / 1000.0
# 482.0 / 1000.0
# 483.0 / 1000.0
# 484.0 / 1000.0
# 485.0 / 1000.0
# 486.0 / 1000.0
# 487.0 / 1000.0
# 488.0 / 1000.0
# 489.0 / 1000.0
# 490.0 / 1000.0
# 491.0 / 1000.0
# 492.0 / 1000.0
# 493.0 / 1000.0
# 494.0 / 1000.0
# 495.0 / 1000.0
# 496.0 / 1000.0
# 497.0 / 1000.0
# 498.0 / 1000.0
# 499.0 / 1000.0
# 500.0 / 1000.0
# 501.0 / 1000.0
# 502.0 / 1000.0
# 503.0 / 1000.0
# 504.0 / 1000.0
# 505.0 / 1000.0
# 506.0 / 1000.0
# 507.0 / 1000.0
# 508.0 / 1000.0
# 509.0 / 1000.0
# 510.0 / 1000.0
# 511.0 / 1000.0
# 512.0 / 1000.0
# 513.0 / 1000.0
# 514.0 / 1000.0
# 515.0 / 1000.0
# 516.0 / 1000.0
# 517.0 / 1000.0
# 518.0 / 1000.0
# 519.0 / 1000.0
# 520.0 / 1000.0
# 521.0 / 1000.0
# 522.0 / 1000.0
# 523.0 / 1000.0
# 524.0 / 1000.0
# 525.0 / 1000.0
# 526.0 / 1000.0
# 527.0 / 1000.0
# 528.0 / 1000.0
# 529.0 / 1000.0
# 530.0 / 1000.0
# 531.0 / 1000.0
# 532.0 / 1000.0
# 533.0 / 1000.0
# 534.0 / 1000.0
# 535.0 / 1000.0
# 536.0 / 1000.0
# 537.0 / 1000.0
# 538.0 / 1000.0
# 539.0 / 1000.0
# 540.0 / 1000.0
# 541.0 / 1000.0
# 542.0 / 1000.0
# 543.0 / 1000.0
# 544.0 / 1000.0
# 545.0 / 1000.0
# 546.0 / 1000.0
# 547.0 / 1000.0
# 548.0 / 1000.0
# 549.0 / 1000.0
# 550.0 / 1000.0
# 551.0 / 1000.0
# 552.0 / 1000.0
# 553.0 / 1000.0
# 554.0 / 1000.0
# 555.0 / 1000.0
# 556.0 / 1000.0
# 557.0 / 1000.0
# 558.0 / 1000.0
# 559.0 / 1000.0
# 560.0 / 1000.0
# 561.0 / 1000.0
# 562.0 / 1000.0
# 563.0 / 1000.0
# 564.0 / 1000.0
# 565.0 / 1000.0
# 566.0 / 1000.0
# 567.0 / 1000.0
# 568.0 / 1000.0
# 569.0 / 1000.0
# 570.0 / 1000.0
# 571.0 / 1000.0
# 572.0 / 1000.0
# 573.0 / 1000.0
# 574.0 / 1000.0
# 575.0 / 1000.0
# 576.0 / 1000.0
# 577.0 / 1000.0
# 578.0 / 1000.0
# 579.0 / 1000.0
# 580.0 / 1000.0
# 581.0 / 1000.0
# 582.0 / 1000.0
# 583.0 / 1000.0
# 584.0 / 1000.0
# 585.0 / 1000.0
# 586.0 / 1000.0
# 587.0 / 1000.0
# 588.0 / 1000.0
# 589.0 / 1000.0
# 590.0 / 1000.0
# 591.0 / 1000.0
# 592.0 / 1000.0
# 593.0 / 1000.0
# 594.0 / 1000.0
# 595.0 / 1000.0
# 596.0 / 1000.0
# 597.0 / 1000.0
# 598.0 / 1000.0
# 599.0 / 1000.0
# 600.0 / 1000.0
# 601.0 / 1000.0
# 602.0 / 1000.0
# 603.0 / 1000.0
# 604.0 / 1000.0
# 605.0 / 1000.0
# 606.0 / 1000.0
# 607.0 / 1000.0
# 608.0 / 1000.0
# 609.0 / 1000.0
# 610.0 / 1000.0
# 611.0 / 1000.0
# 612.0 / 1000.0
# 613.0 / 1000.0
# 614.0 / 1000.0
# 615.0 / 1000.0
# 616.0 / 1000.0
# 617.0 / 1000.0
# 618.0 / 1000.0
# 619.0 / 1000.0
# 620.0 / 1000.0
# 621.0 / 1000.0
# 622.0 / 1000.0
# 623.0 / 1000.0
# 624.0 / 1000.0
# 625.0 / 1000.0
# 626.0 / 1000.0
# 627.0 / 1000.0
# 628.0 / 1000.0
# 629.0 / 1000.0
# 630.0 / 1000.0
# 631.0 / 1000.0
# 632.0 / 1000.0
# 633.0 / 1000.0
# 634.0 / 1000.0
# 635.0 / 1000.0
# 636.0 / 1000.0
# 637.0 / 1000.0
# 638.0 / 1000.0
# 639.0 / 1000.0
# 640.0 / 1000.0
# 641.0 / 1000.0
# 642.0 / 1000.0
# 643.0 / 1000.0
# 644.0 / 1000.0
# 645.0 / 1000.0
# 646.0 / 1000.0
# 647.0 / 1000.0
# 648.0 / 1000.0
# 649.0 / 1000.0
# 650.0 / 1000.0
# 651.0 / 1000.0
# 652.0 / 1000.0
# 653.0 / 1000.0
# 654.0 / 1000.0
# 655.0 / 1000.0
# 656.0 / 1000.0
# 657.0 / 1000.0
# 658.0 / 1000.0
# 659.0 / 1000.0
# 660.0 / 1000.0
# 661.0 / 1000.0
# 662.0 / 1000.0
# 663.0 / 1000.0
# 664.0 / 1000.0
# 665.0 / 1000.0
# 666.0 / 1000.0
# 667.0 / 1000.0
# 668.0 / 1000.0
# 669.0 / 1000.0
# 670.0 / 1000.0
# 671.0 / 1000.0
# 672.0 / 1000.0
# 673.0 / 1000.0
# 674.0 / 1000.0
# 675.0 / 1000.0
# 676.0 / 1000.0
# 677.0 / 1000.0
# 678.0 / 1000.0
# 679.0 / 1000.0
# 680.0 / 1000.0
# 681.0 / 1000.0
# 682.0 / 1000.0
# 683.0 / 1000.0
# 684.0 / 1000.0
# 685.0 / 1000.0
# 686.0 / 1000.0
# 687.0 / 1000.0
# 688.0 / 1000.0
# 689.0 / 1000.0
# 690.0 / 1000.0
# 691.0 / 1000.0
# 692.0 / 1000.0
# 693.0 / 1000.0
# 694.0 / 1000.0
# 695.0 / 1000.0
# 696.0 / 1000.0
# 697.0 / 1000.0
# 698.0 / 1000.0
# 699.0 / 1000.0
# 700.0 / 1000.0
# 701.0 / 1000.0
# 702.0 / 1000.0
# 703.0 / 1000.0
# 704.0 / 1000.0
# 705.0 / 1000.0
# 706.0 / 1000.0
# 707.0 / 1000.0
# 708.0 / 1000.0
# 709.0 / 1000.0
# 710.0 / 1000.0
# 711.0 / 1000.0
# 712.0 / 1000.0
# 713.0 / 1000.0
# 714.0 / 1000.0
# 715.0 / 1000.0
# 716.0 / 1000.0
# 717.0 / 1000.0
# 718.0 / 1000.0
# 719.0 / 1000.0
# 720.0 / 1000.0
# 721.0 / 1000.0
# 722.0 / 1000.0
# 723.0 / 1000.0
# 724.0 / 1000.0
# 725.0 / 1000.0
# 726.0 / 1000.0
# 727.0 / 1000.0
# 728.0 / 1000.0
# 729.0 / 1000.0
# 730.0 / 1000.0
# 731.0 / 1000.0
# 732.0 / 1000.0
# 733.0 / 1000.0
# 734.0 / 1000.0
# 735.0 / 1000.0
# 736.0 / 1000.0
# 737.0 / 1000.0
# 738.0 / 1000.0
# 739.0 / 1000.0
# 740.0 / 1000.0
# 741.0 / 1000.0
# 742.0 / 1000.0
# 743.0 / 1000.0
# 744.0 / 1000.0
# 745.0 / 1000.0
# 746.0 / 1000.0
# 747.0 / 1000.0
# 748.0 / 1000.0
# 749.0 / 1000.0
# 750.0 / 1000.0
# 751.0 / 1000.0
# 752.0 / 1000.0
# 753.0 / 1000.0
# 754.0 / 1000.0
# 755.0 / 1000.0
# 756.0 / 1000.0
# 757.0 / 1000.0
# 758.0 / 1000.0
# 759.0 / 1000.0
# 760.0 / 1000.0
# 761.0 / 1000.0
# 762.0 / 1000.0
# 763.0 / 1000.0
# 764.0 / 1000.0
# 765.0 / 1000.0
# 766.0 / 1000.0
# 767.0 / 1000.0
# 768.0 / 1000.0
# 769.0 / 1000.0
# 770.0 / 1000.0
# 771.0 / 1000.0
# 772.0 / 1000.0
# 773.0 / 1000.0
# 774.0 / 1000.0
# 775.0 / 1000.0
# 776.0 / 1000.0
# 777.0 / 1000.0
# 778.0 / 1000.0
# 779.0 / 1000.0
# 780.0 / 1000.0
# 781.0 / 1000.0
# 782.0 / 1000.0
# 783.0 / 1000.0
# 784.0 / 1000.0
# 785.0 / 1000.0
# 786.0 / 1000.0
# 787.0 / 1000.0
# 788.0 / 1000.0
# 789.0 / 1000.0
# 790.0 / 1000.0
# 791.0 / 1000.0
# 792.0 / 1000.0
# 793.0 / 1000.0
# 794.0 / 1000.0
# 795.0 / 1000.0
# 796.0 / 1000.0
# 797.0 / 1000.0
# 798.0 / 1000.0
# 799.0 / 1000.0
# 800.0 / 1000.0
# 801.0 / 1000.0
# 802.0 / 1000.0
# 803.0 / 1000.0
# 804.0 / 1000.0
# 805.0 / 1000.0
# 806.0 / 1000.0
# 807.0 / 1000.0
# 808.0 / 1000.0
# 809.0 / 1000.0
# 810.0 / 1000.0
# 811.0 / 1000.0
# 812.0 / 1000.0
# 813.0 / 1000.0
# 814.0 / 1000.0
# 815.0 / 1000.0
# 816.0 / 1000.0
# 817.0 / 1000.0
# 818.0 / 1000.0
# 819.0 / 1000.0
# 820.0 / 1000.0
# 821.0 / 1000.0
# 822.0 / 1000.0
# 823.0 / 1000.0
# 824.0 / 1000.0
# 825.0 / 1000.0
# 826.0 / 1000.0
# 827.0 / 1000.0
# 828.0 / 1000.0
# 829.0 / 1000.0
# 830.0 / 1000.0
# 831.0 / 1000.0
# 832.0 / 1000.0
# 833.0 / 1000.0
# 834.0 / 1000.0
# 835.0 / 1000.0
# 836.0 / 1000.0
# 837.0 / 1000.0
# 838.0 / 1000.0
# 839.0 / 1000.0
# 840.0 / 1000.0
# 841.0 / 1000.0
# 842.0 / 1000.0
# 843.0 / 1000.0
# 844.0 / 1000.0
# 845.0 / 1000.0
# 846.0 / 1000.0
# 847.0 / 1000.0
# 848.0 / 1000.0
# 849.0 / 1000.0
# 850.0 / 1000.0
# 851.0 / 1000.0
# 852.0 / 1000.0
# 853.0 / 1000.0
# 854.0 / 1000.0
# 855.0 / 1000.0
# 856.0 / 1000.0
# 857.0 / 1000.0
# 858.0 / 1000.0
# 859.0 / 1000.0
# 860.0 / 1000.0
# 861.0 / 1000.0
# 862.0 / 1000.0
# 863.0 / 1000.0
# 864.0 / 1000.0
# 865.0 / 1000.0
# 866.0 / 1000.0
# 867.0 / 1000.0
# 868.0 / 1000.0
# 869.0 / 1000.0
# 870.0 / 1000.0
# 871.0 / 1000.0
# 872.0 / 1000.0
# 873.0 / 1000.0
# 874.0 / 1000.0
# 875.0 / 1000.0
# 876.0 / 1000.0
# 877.0 / 1000.0
# 878.0 / 1000.0
# 879.0 / 1000.0
# 880.0 / 1000.0
# 881.0 / 1000.0
# 882.0 / 1000.0
# 883.0 / 1000.0
# 884.0 / 1000.0
# 885.0 / 1000.0
# 886.0 / 1000.0
# 887.0 / 1000.0
# 888.0 / 1000.0
# 889.0 / 1000.0
# 890.0 / 1000.0
# 891.0 / 1000.0
# 892.0 / 1000.0
# 893.0 / 1000.0
# 894.0 / 1000.0
# 895.0 / 1000.0
# 896.0 / 1000.0
# 897.0 / 1000.0
# 898.0 / 1000.0
# 899.0 / 1000.0
# 900.0 / 1000.0
# 901.0 / 1000.0
# 902.0 / 1000.0
# 903.0 / 1000.0
# 904.0 / 1000.0
# 905.0 / 1000.0
# 906.0 / 1000.0
# 907.0 / 1000.0
# 908.0 / 1000.0
# 909.0 / 1000.0
# 910.0 / 1000.0
# 911.0 / 1000.0
# 912.0 / 1000.0
# 913.0 / 1000.0
# 914.0 / 1000.0
# 915.0 / 1000.0
# 916.0 / 1000.0
# 917.0 / 1000.0
# 918.0 / 1000.0
# 919.0 / 1000.0
# 920.0 / 1000.0
# 921.0 / 1000.0
# 922.0 / 1000.0
# 923.0 / 1000.0
# 924.0 / 1000.0
# 925.0 / 1000.0
# 926.0 / 1000.0
# 927.0 / 1000.0
# 928.0 / 1000.0
# 929.0 / 1000.0
# 930.0 / 1000.0
# 931.0 / 1000.0
# 932.0 / 1000.0
# 933.0 / 1000.0
# 934.0 / 1000.0
# 935.0 / 1000.0
# 936.0 / 1000.0
# 937.0 / 1000.0
# 938.0 / 1000.0
# 939.0 / 1000.0
# 940.0 / 1000.0
# 941.0 / 1000.0
# 942.0 / 1000.0
# 943.0 / 1000.0
# 944.0 / 1000.0
# 945.0 / 1000.0
# 946.0 / 1000.0
# 947.0 / 1000.0
# 948.0 / 1000.0
# 949.0 / 1000.0
# 950.0 / 1000.0
# 951.0 / 1000.0
# 952.0 / 1000.0
# 953.0 / 1000.0
# 954.0 / 1000.0
# 955.0 / 1000.0
# 956.0 / 1000.0
# 957.0 / 1000.0
# 958.0 / 1000.0
# 959.0 / 1000.0
# 960.0 / 1000.0
# 961.0 / 1000.0
# 962.0 / 1000.0
# 963.0 / 1000.0
# 964.0 / 1000.0
# 965.0 / 1000.0
# 966.0 / 1000.0
# 967.0 / 1000.0
# 968.0 / 1000.0
# 969.0 / 1000.0
# 970.0 / 1000.0
# 971.0 / 1000.0
# 972.0 / 1000.0
# 973.0 / 1000.0
# 974.0 / 1000.0
# 975.0 / 1000.0
# 976.0 / 1000.0
# 977.0 / 1000.0
# 978.0 / 1000.0
# 979.0 / 1000.0
# 980.0 / 1000.0
# 981.0 / 1000.0
# 982.0 / 1000.0
# 983.0 / 1000.0
# 984.0 / 1000.0
# 985.0 / 1000.0
# 986.0 / 1000.0
# 987.0 / 1000.0
# 988.0 / 1000.0
# 989.0 / 1000.0
# 990.0 / 1000.0
# 991.0 / 1000.0
# 992.0 / 1000.0
# 993.0 / 1000.0
# 994.0 / 1000.0
# 995.0 / 1000.0
# 996.0 / 1000.0
# 997.0 / 1000.0
# 998.0 / 1000.0
# 999.0 / 1000.0

# %%
len(ind)
# Out:
# 152249

# %%
theta = np.delete(theta,ind)
E = np.delete(E,ind)
M = np.delete(M,ind)

# %%
xy = np.matrix([theta,E])
xy = xy.T
xy = xy.A
xy = xy.reshape(len(E),2)
print(xy.shape,type(xy))
# Out:
# (9847751, 2) <class 'numpy.ndarray'>

# %% [markdown]
# ## Grafico dati

# %% [markdown]
# ## Grafico dei dati divisi in 2 strisce di energia

# %%
E2Cut = (3000 + 348)/2

M_2ECut_1 = []
theta_2ECut_1 = []
E_2ECut_1 = []

M_2ECut_2 = []
theta_2ECut_2 = []
E_2ECut_2 = []

for i in range(len(M)):
    if E[i] > E2Cut:
        theta_2ECut_1.append(theta[i])
        E_2ECut_1.append(E[i])
        M_2ECut_1.append(M[i])
    else:
        theta_2ECut_2.append(theta[i])
        E_2ECut_2.append(E[i])
        M_2ECut_2.append(M[i])

# %% [markdown]
# ### Grafico con energia [1674,3000] Gev

# %%
M_2ECut_1 = np.array(M_2ECut_1)
theta_2ECut_1 = np.array(theta_2ECut_1)
E_2ECut_1 = np.array(E_2ECut_1)

# %%
xy_2ECut_1 = np.matrix([theta_2ECut_1,E_2ECut_1])
xy_2ECut_1 = xy_2ECut_1.T
xy_2ECut_1 = xy_2ECut_1.A
xy_2ECut_1 = xy_2ECut_1.reshape(len(E_2ECut_1),2)
print(xy_2ECut_1.shape,type(xy_2ECut_1))
print(xy_2ECut_1[:10])
# Out:
# (4919908, 2) <class 'numpy.ndarray'>
# [[1.83688592e+00 2.97782065e+03]
#  [2.65622383e+00 2.47307898e+03]
#  [2.49310544e+00 2.71302915e+03]
#  [2.86441300e+00 2.29459685e+03]
#  [1.60173495e+00 2.63383931e+03]
#  [1.64077801e+00 1.83967075e+03]
#  [1.33758723e+00 2.83705024e+03]
#  [1.77381009e+00 1.85560824e+03]
#  [1.64335981e+00 2.40859267e+03]
#  [1.42996559e+00 2.58749808e+03]]

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_2ECut_1[:100000,0], xy_2ECut_1[:100000,1], M_2ECut_1[:100000], label='Training', alpha=0.35)
ax.set_xlabel('$ \u03B8 $', fontsize=15)
ax.set_ylabel('$ \u221A s$', fontsize=15)
ax.set_zlabel('$M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutrealdata.png')
plt.show()

# %% [markdown]
# ### Grafico con energia [348,1674] Gev

# %%
M_2ECut_2 = np.array(M_2ECut_2)
theta_2ECut_2 = np.array(theta_2ECut_2)
E_2ECut_2 = np.array(E_2ECut_2)

# %%
xy_2ECut_2 = np.matrix([theta_2ECut_2,E_2ECut_2])
xy_2ECut_2 = xy_2ECut_2.T
xy_2ECut_2 = xy_2ECut_2.A
xy_2ECut_2 = xy_2ECut_2.reshape(len(E_2ECut_2),2)
print(xy_2ECut_2.shape,type(xy_2ECut_2))
print(xy_2ECut_2[:10])
# Out:
# (4927843, 2) <class 'numpy.ndarray'>
# [[1.98133779e+00 5.55802374e+02]
#  [1.30064346e+00 6.39377210e+02]
#  [2.30987617e+00 3.96585120e+02]
#  [1.99796098e+00 5.66867887e+02]
#  [1.62815827e+00 1.19161440e+03]
#  [1.47484901e+00 9.01647692e+02]
#  [1.80764197e+00 1.24742984e+03]
#  [5.49948022e-01 4.32935785e+02]
#  [2.13242044e+00 4.37478207e+02]
#  [1.59722516e+00 1.17658700e+03]]

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_2ECut_2[:50000,0], xy_2ECut_2[:50000,1], M_2ECut_2[:50000], label='Training', alpha=0.35)
ax.set_xlabel('$ \u03B8 $', fontsize=15)
ax.set_ylabel('$ \u221A s$', fontsize=15)
ax.set_zlabel('$M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutrealdata1.png')
plt.show()

# %% [markdown]
# # Reti Neurali
# ## Preparazione

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras import optimizers, losses, metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras import activations
from tensorflow.keras.callbacks import EarlyStopping

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from numpy import mean
from numpy import std

# %%
def baseline_model_dataset(layers, lr=0.001, activation='relu', loss='mean_squared_error'):
        'define and compile model with fixing weight initialisers and a random dataset'
        # create model
        # at some point can use new Keras tuning feature for optimising this model

        
        model = Sequential()
        model.add(Dense(10, input_shape=(2,),activation='relu'))
        model.add(Dense(layers[0], input_dim=(2))) #dim può essere anche "2", non lo so
        if activation == 'tanh':
            model.add(Activation(activations.tanh))
        elif activation == 'relu':
            model.add(Activation(activations.relu))
        else:
            raise ValueError('activation supported are either tanh or relu, you have used {}'.format(activation))

        for i in range(1,len(layers)):
            model.add(Dense(layers[i]))
            if activation == 'tanh':
                model.add(Activation(activations.tanh))
            elif activation == 'relu':
                model.add(Activation(activations.relu))

        model.add(Dense(1))
        # Compile model
        model.compile(optimizer = Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = loss)
        
        return model

# %%
def baseline_model(layers, lr=0.001, activation='tanh', loss='mean_squared_error'):
        'define and compile model with a fixed dataset but random weights'
        # create model
        # at some point can use new Keras tuning feature for optimising this model
        model = Sequential()
        model.add(Dense(layers[0], input_dim=(2)))
        if activation == 'tanh':
            model.add(Activation(activations.tanh))
        elif activation == 'relu':
            model.add(Activation(activations.relu))
        else:
            raise ValueError('activation supported are either tanh or relu, you have used {}'.format(activation))
        
        for i in range(1, len(layers)):
            model.add(Dense(layers[i]))
            if activation == 'tanh':
                model.add(Activation(activations.tanh))
            elif activation == 'relu':
                model.add(Activation(activations.relu))

        model.add(Dense(1))
        # Compile model
        model.compile(optimizer = Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = loss)
        
        return model

# %%
def get_dataset(xy, M, input_scaler, output_scaler, interval):
	# generate dataset
	#X, y = make_regression(n_samples=1000, n_features=20, noise=0.1, random_state=1)
	# split into train and test
	#n_train = 500
    n_train = int(interval / 100 * 70)
    n_valid = int(interval / 100 * 30)
    print ("# training points :",n_train,"\n# validation points: ", n_valid)
    trainX, testX = xy[:n_train], xy[n_train:n_train + n_valid]
    trainy, testy = M[:n_train], M[n_train:n_train + n_valid]
	# scale inputs
    if input_scaler is not None:
        # fit scaler
        input_scaler.fit(trainX)
        # transform training dataset
        trainX = input_scaler.transform(trainX)
        # transform test dataset
        testX = input_scaler.transform(testX)
    if output_scaler is not None:
        # reshape 1d arrays to 2d arrays
        trainy = trainy.reshape(len(trainy), 1)
        testy = testy.reshape(len(testy), 1)
        # fit scaler on training dataset
        output_scaler.fit(trainy)
        # transform training dataset
        trainy = output_scaler.transform(trainy)
        # transform test dataset
        testy = output_scaler.transform(testy)
    return trainX, trainy, testX, testy, output_scaler, input_scaler

# %%
def prediction_NN(begin ,dim, xy, M, scaler_output, scaler_input):
    xy_valid = xy[begin:begin+dim]
    scaler_input.fit(xy_valid)
    #transform training dataset
    xy_valid = scaler_input.transform(xy_valid)
    #transform test dataset

    z_valid = M[begin:begin+dim]
    z_valid = z_valid.reshape(len(z_valid), 1)
    #fit scaler on training dataset
    scaler_output.fit(z_valid)
    # transform training dataset
    z_valid = scaler_output.transform(z_valid)
    # transform test dataset
    
    return xy_valid, z_valid

# %%
def rescale(xy_valid, z_predicted, z_valid, scaler_input, scaler_output):
    xy_valid = scaler_input.inverse_transform(xy_valid)
    z_predicted = scaler_output.inverse_transform(z_predicted)
    z_predicted = z_predicted.reshape(len(z_predicted),)
    z_valid = scaler_output.inverse_transform(z_valid)
    z_valid = z_valid.reshape(len(z_valid),)
    return xy_valid, z_predicted, z_valid

# %%
def relative_error(z_predicted, z_valid):
    err = abs(np.diff([z_predicted,z_valid],axis=0))
    err = err.reshape(len(z_predicted),)
    err = np.divide(err,z_valid)
    return err

# %%
def array_for_error_map (val_ang, val_en, cut_value, xy_valid, err, gg, dim):
    err_map = np.zeros((dim, dim))
    err_counter = np.zeros((dim,dim))

    if gg == 'ang':
        for i in range(len(xy_valid)):
            for j in range(dim):
                for k in range(dim):
                    if xy_valid[i,0] > cut_value + val_ang*(k) and xy_valid[i,0] < cut_value + val_ang*(k+1) and xy_valid[i,1] > 346 + val_en*j and xy_valid[i,1] < 346 + val_en*(j+1):
                        err_map[j,k] += err[i]
                        #print(err_map[k,j])
                        err_counter[k,j] += 1
    elif gg == 'en':
        for i in range(len(xy_valid)):
            for j in range(dim):
                for k in range(dim):
                    if xy_valid[i,0] > val_ang*(k) and xy_valid[i,0] < val_ang*(k+1) and xy_valid[i,1] > cut_value + val_en*j and xy_valid[i,1] < cut_value + val_en*(j+1):
                        err_map[k,j] += err[i]
                        #print(err_map[k,j])
                        err_counter[k,j] += 1
    else:
        raise ValueError('You can pick ang or en, you have used {}'.format(gg))
        
        
                    
    for j in range(dim):
        for k in range(dim):
            err_map[k,j] /= err_counter[k,j]
            
    return err_map

# %%
def array_for_error_map_1 (val_ang, val_en, cut_value_ang, cut_value_en, xy_valid, err, dim):
    err_map = np.zeros((dim, dim))
    err_counter = np.zeros((dim,dim))

    for i in range(len(xy_valid)):
        for j in range(dim):
            for k in range(dim):
                if xy_valid[i,0] > cut_value_ang + val_ang*(k) and xy_valid[i,0] < cut_value_ang + val_ang*(k+1) and xy_valid[i,1] > cut_value_en + val_en*j and xy_valid[i,1] < cut_value_en + val_en*(j+1):
                    err_map[j,k] += err[i]
                    #print(err_map[k,j])
                    err_counter[k,j] += 1
                            
    for j in range(dim):
        for k in range(dim):
            err_map[k,j] /= err_counter[k,j]
            
    return err_map

# %% [markdown]
# # Rete Neurale #1

# %% [markdown]
# Prima striscia

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_2ECut_1, M_2ECut_1, MinMaxScaler(), MinMaxScaler(),3000000)
# Out:
# # training points : 2100000
# # validation points:  900000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model1 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# activation (Activation)      (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                840
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                820
# _________________________________________________________________
# activation_2 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,931
# Trainable params: 1,931
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model1.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time1 = stop - start
print('Time: ', training_time1)
# Out:
# Epoch 1/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 0.0033 - val_loss: 7.8203e-04
# Epoch 2/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 5.4960e-04 - val_loss: 3.3949e-04
# Epoch 3/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.2319e-04 - val_loss: 2.0144e-04
# Epoch 4/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.3838e-04 - val_loss: 1.7538e-04
# Epoch 5/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.2005e-04 - val_loss: 2.5351e-04
# Epoch 6/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.8370e-04 - val_loss: 1.5103e-04
# Epoch 7/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.4524e-04 - val_loss: 1.0753e-04
# Epoch 8/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.1214e-04 - val_loss: 8.9704e-05
# Epoch 9/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 9.0863e-05 - val_loss: 6.7888e-05
# Epoch 10/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.9797e-05 - val_loss: 5.4210e-05
# Epoch 11/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.5560e-05 - val_loss: 4.3267e-05
# Epoch 12/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.1295e-05 - val_loss: 9.3001e-05
# Epoch 13/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6.9733e-05 - val_loss: 1.7987e-04
# Epoch 14/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6.5117e-05 - val_loss: 4.7321e-05
# Epoch 15/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 5.3964e-05 - val_loss: 2.6142e-05
# Epoch 16/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.9351e-05 - val_loss: 3.7297e-05
# Epoch 17/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.4335e-05 - val_loss: 2.4931e-05
# Epoch 18/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 3.2148e-05 - val_loss: 1.9952e-05
# Epoch 19/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.9100e-05 - val_loss: 2.7823e-05
# Epoch 20/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 2.5599e-05 - val_loss: 1.5787e-05
# Epoch 21/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.1837e-05 - val_loss: 1.3208e-05
# Epoch 22/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.5851e-05 - val_loss: 7.5765e-06
# Epoch 23/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.1481e-05 - val_loss: 1.3016e-05
# Epoch 24/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.0052e-05 - val_loss: 6.0944e-06
# Epoch 25/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 9.2138e-06 - val_loss: 4.1703e-06
# Epoch 26/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 8.3723e-06 - val_loss: 1.1813e-05
# Epoch 27/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.9151e-06 - val_loss: 1.2652e-05
# Epoch 28/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.9543e-06 - val_loss: 1.6606e-05
# Epoch 29/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.4787e-06 - val_loss: 7.7488e-06
# Epoch 30/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.1349e-06 - val_loss: 3.6016e-06
# Epoch 31/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6
10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.2832e-07 - val_loss: 3.3507e-08
# Epoch 845/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.1431e-07 - val_loss: 3.9338e-08
# Epoch 846/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.9408e-07 - val_loss: 1.0881e-07
# Epoch 847/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.5819e-07 - val_loss: 1.0171e-08
# Epoch 848/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.2086e-07 - val_loss: 3.6256e-09
# Epoch 849/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.4318e-07 - val_loss: 2.7609e-08
# Epoch 850/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.5921e-07 - val_loss: 7.7192e-07
# Epoch 851/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.7028e-07 - val_loss: 1.5564e-07
# Epoch 852/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.0585e-07 - val_loss: 2.4312e-08
# Epoch 853/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.9833e-07 - val_loss: 3.1925e-07
# Epoch 854/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.7955e-07 - val_loss: 5.1438e-09
# Epoch 855/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.7495e-07 - val_loss: 2.7090e-08
# Epoch 856/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.9786e-07 - val_loss: 3.4568e-07
# Epoch 857/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.2033e-07 - val_loss: 1.0484e-08
# Epoch 858/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.9284e-07 - val_loss: 4.1100e-09
# Epoch 859/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.0009e-07 - val_loss: 8.3042e-07
# Epoch 860/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 2.7926e-07 - val_loss: 8.7451e-09
# Epoch 861/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.7007e-07 - val_loss: 3.7680e-08
# Epoch 862/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.2251e-07 - val_loss: 2.2843e-08
# Epoch 863/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.6536e-07 - val_loss: 1.8581e-06
# Epoch 864/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 4.0731e-07 - val_loss: 1.2844e-08
# Epoch 865/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.0951e-07 - val_loss: 2.5550e-07
# Time:  7804.8249197

# %%
score = model1.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 15625/15625 [==============================] - 15s 972us/step - loss: 2.5960e-04
#
# Test loss: 0.00025959915365092456

# %%
xy_valid, z_valid = prediction_NN(3000000,1000000, xy_2ECut_1, M_2ECut_1, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model1.predict(xy_valid)
stop = timeit.default_timer()
prediction_time1 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutpredictedfirst.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  22.986619500001325

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_1 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_1), n_bins, range=(0,5))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE2CutEnhistofirst.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E2Cut - 346)/10

# %%
err_map_1 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E2Cut, xy_valid, err_1, 10)

# %%
ang1 = []
En1 = []
for i in range(10):
    ang1.append(round(angle_cut1 + (i+1)*val_ang,2))
    En1.append(round(E2Cut+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_1),xticklabels = ang1, yticklabels = En1)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapfirst.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time1)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time1)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 7804.8249197
# Tempo di predizione della rete di 1000000 elementi: 22.986619500001325

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 1000000 elementi con MadGraph: 14.287322861839217

# %%
n_min1 = round(training_time1/(t/len(M)-prediction_time1/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min1)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -897178846

# %%
err_1
# Out:
# array([0.09290817, 0.0244733 , 0.01901172, ..., 0.06901718, 0.12434866,
#        0.01464656])

# %% [markdown]
# # Rete Neurale #2

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_2ECut_1, M_2ECut_1, MinMaxScaler(), MinMaxScaler(),3000000)
# Out:
# # training points : 2100000
# # validation points:  900000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model2 = tf.keras.Sequential()
model2.add(Dense(15, input_shape=(2,),activation='relu'))
model2.add(Dense(40, input_shape=(2,),activation='tanh'))
model2.add(Dense(45, input_shape=(2,),activation='tanh'))
model2.add(Dense(30, input_shape=(2,),activation='tanh'))
model2.add(Dense(15, input_shape=(2,),activation='relu'))
model2.add(Dense(1))
model2.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 15)                45
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                640
# _________________________________________________________________
# dense_7 (Dense)              (None, 45)                1845
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                1380
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model2.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=
10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 6.8641e-07 - val_loss: 4.7430e-08
# Epoch 293/10000
# 4102/4102 [==============================] - 10s 3ms/step - loss: 5.9410e-07 - val_loss: 1.2483e-07
# Epoch 294/10000
# 4102/4102 [==============================] - 10s 3ms/step - loss: 4.7047e-07 - val_loss: 1.0862e-07
# Epoch 295/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 6.0412e-07 - val_loss: 2.1635e-07
# Time:  3122.7913554999996

# %%
score = model2.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 15625/15625 [==============================] - 15s 972us/step - loss: 2.5960e-04
#
# Test loss: 0.00025959915365092456

# %%
xy_valid, z_valid = prediction_NN(3000000,1000000, xy_2ECut_1, M_2ECut_1, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model2.predict(xy_valid)
stop = timeit.default_timer()
prediction_time2 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutpredictedsecond.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  22.986619500001325

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_2 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_2), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE2Cuthistosecond.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E2Cut - 346)/10

# %%
err_map_2 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E2Cut, xy_valid, err_2, 10)

# %%
ang2 = []
En2 = []
for i in range(10):
    ang2.append(round(angle_cut1 + (i+1)*val_ang,2))
    En2.append(round(E2Cut+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_2),xticklabels = ang2, yticklabels = En2)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapsecond.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time2)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time2)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 3122.7913554999996
# Tempo di predizione della rete di 1000000 elementi: 23.29460889999973

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 1000000 elementi con MadGraph: 14.287322861839217

# %%
n_min2 = round(training_time2/(t/len(M)-prediction_time2/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min2)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -346696146

# %%
err_1
# Out:
# array([0.09290817, 0.0244733 , 0.01901172, ..., 0.06901718, 0.12434866,
#        0.01464656])

# %% [markdown]
# # Rete Neurale #3

# %% [markdown]
# Seconda parte

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_2ECut_2, M_2ECut_2, MinMaxScaler(), MinMaxScaler(),3000000)
# Out:
# # training points : 2100000
# # validation points:  900000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model3 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                220
# _________________________________________________________________
# activation_3 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 40)                840
# _________________________________________________________________
# activation_4 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                820
# _________________________________________________________________
# activation_5 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 1,931
# Trainable params: 1,931
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model3.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time3 = stop - start
print('Time: ', training_time1)
# Out:
# Epoch 1/10000
# 4102/4102 [==============================] - 10s 2ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 2/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 8.9762e-04 - val_loss: 4.4260e-04
# Epoch 3/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.2983e-04 - val_loss: 2.6396e-04
# Epoch 4/10000
# 4102/4102 [==============================] - 13s 3ms/step - loss: 2.1882e-04 - val_loss: 1.4962e-04
# Epoch 5/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.5017e-04 - val_loss: 9.5333e-05
# Epoch 6/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.0216e-04 - val_loss: 7.6031e-05
# Epoch 7/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6.2542e-05 - val_loss: 3.2533e-05
# Epoch 8/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 3.0380e-05 - val_loss: 2.1405e-05
# Epoch 9/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.9210e-05 - val_loss: 9.5945e-06
# Epoch 10/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.5281e-05 - val_loss: 6.9420e-06
# Epoch 11/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.3250e-05 - val_loss: 6.4972e-06
# Epoch 12/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.1869e-05 - val_loss: 1.1523e-05
# Epoch 13/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 1.0709e-05 - val_loss: 6.1752e-06
# Epoch 14/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 9.5577e-06 - val_loss: 6.0734e-06
# Epoch 15/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 8.6856e-06 - val_loss: 3.3772e-06
# Epoch 16/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.9412e-06 - val_loss: 3.6891e-06
# Epoch 17/10000
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6
10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.1070e-07 - val_loss: 1.5473e-08
# Epoch 400/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 7.8076e-07 - val_loss: 9.1138e-07
# Epoch 401/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 7.2081e-07 - val_loss: 4.3192e-08
# Epoch 402/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.0264e-07 - val_loss: 2.4535e-07
# Epoch 403/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.3036e-07 - val_loss: 3.9892e-08
# Epoch 404/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.7600e-07 - val_loss: 1.6499e-06
# Epoch 405/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 8.6709e-07 - val_loss: 1.2134e-07
# Epoch 406/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 7.6594e-07 - val_loss: 2.7294e-07
# Epoch 407/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.2610e-07 - val_loss: 2.0469e-08
# Epoch 408/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 5.6895e-07 - val_loss: 1.1403e-06
# Epoch 409/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 7.0896e-07 - val_loss: 4.8702e-06
# Epoch 410/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 8.7273e-07 - val_loss: 1.6626e-08
# Epoch 411/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 4.7389e-07 - val_loss: 6.1692e-08
# Epoch 412/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.5689e-07 - val_loss: 1.1273e-06
# Epoch 413/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.4250e-07 - val_loss: 3.9749e-08
# Epoch 414/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 5.3479e-07 - val_loss: 5.5241e-07
# Epoch 415/10000
# 4102/4102 [==============================] - 8s 2ms/step - loss: 6.3892e-07 - val_loss: 6.3648e-07
# Epoch 416/10000
# 3963/4102 [===========================>..] - ETA: 0s - loss: 7.1482e-07
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
score = model3.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 15625/15625 [==============================] - 15s 972us/step - loss: 2.5960e-04
#
# Test loss: 0.00025959915365092456

# %%
xy_valid, z_valid = prediction_NN(3000000,1000000, xy_2ECut_2, M_2ECut_2, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model3.predict(xy_valid)
stop = timeit.default_timer()
prediction_time3 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutpredictedfirst1.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  22.986619500001325

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_3 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_3), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE2Cuthistofirst1.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E2Cut - 346)/10

# %%
err_map_3 = array_for_error_map_1 (val_ang, val_en, angle_cut1, 346, xy_valid, err_3, 10)

# %%
ang3 = []
En3 = []
for i in range(10):
    ang3.append(round(angle_cut1 + (i+1)*val_ang,2))
    En3.append(round(346+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_3),xticklabels = ang3, yticklabels = En3)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapfirst1.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time3)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time3)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 4122.2242109
# Tempo di predizione della rete di 1000000 elementi: 21.437215199999628

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 1000000 elementi con MadGraph: 14.287322861839217

# %%
n_min3 = round(training_time3/(t/len(M)-prediction_time3/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min3)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -576543536

# %% [markdown]
# # Rete Neurale #4

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_2ECut_2, M_2ECut_2, MinMaxScaler(), MinMaxScaler(),3000000)
# Out:
# # training points : 2100000
# # validation points:  900000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model4 = tf.keras.Sequential()
model4.add(Dense(15, input_shape=(2,),activation='relu'))
model4.add(Dense(40, input_shape=(2,),activation='tanh'))
model4.add(Dense(45, input_shape=(2,),activation='tanh'))
model4.add(Dense(30, input_shape=(2,),activation='tanh'))
model4.add(Dense(15, input_shape=(2,),activation='relu'))
model4.add(Dense(1))
model4.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_17 (Dense)             (None, 40)                640
# _________________________________________________________________
# dense_18 (Dense)             (None, 45)                1845
# _________________________________________________________________
# dense_19 (Dense)             (None, 30)                1380
# _________________________________________________________________
# dense_20 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model4.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time4 = stop - start
print('Time: ', training_time4)
# Out:
# Epoch 1/10000
# 4102/4102 [==============================] - 14s 3ms/step - loss: 2.7890e-04 - val_loss: 5.7243e-05
# Epoch 2/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 5
10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6937e-07 - val_loss: 6.5103e-08
# Epoch 500/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.1126e-07 - val_loss: 4.9057e-07
# Epoch 501/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.2099e-07 - val_loss: 4.4774e-06
# Epoch 502/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.5128e-07 - val_loss: 2.7199e-08
# Epoch 503/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.5287e-07 - val_loss: 1.3021e-06
# Epoch 504/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6044e-07 - val_loss: 5.1863e-08
# Epoch 505/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.8162e-07 - val_loss: 4.2232e-08
# Epoch 506/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6857e-07 - val_loss: 2.1382e-07
# Epoch 507/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.4961e-07 - val_loss: 3.3228e-08
# Epoch 508/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.7873e-07 - val_loss: 4.6827e-07
# Epoch 509/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.7485e-07 - val_loss: 2.4083e-07
# Epoch 510/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.2654e-07 - val_loss: 2.0500e-07
# Epoch 511/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.4965e-07 - val_loss: 5.8462e-07
# Epoch 512/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.1596e-07 - val_loss: 1.6522e-07
# Epoch 513/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.2059e-07 - val_loss: 6.6008e-08
# Epoch 514/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.4630e-07 - val_loss: 2.6446e-07
# Epoch 515/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.8606e-07 - val_loss: 1.9807e-08
# Epoch 516/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.8699e-07 - val_loss: 2.3448e-08
# Epoch 517/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.1380e-07 - val_loss: 1.9678e-08
# Epoch 518/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.3770e-07 - val_loss: 9.1530e-08
# Epoch 519/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.7796e-07 - val_loss: 1.3209e-07
# Epoch 520/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.5878e-07 - val_loss: 4.3758e-06
# Epoch 521/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.5035e-07 - val_loss: 2.4374e-07
# Epoch 522/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.0291e-07 - val_loss: 2.5680e-08
# Epoch 523/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.3642e-07 - val_loss: 2.7247e-08
# Epoch 524/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6197e-07 - val_loss: 3.3648e-08
# Epoch 525/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.3327e-07 - val_loss: 3.0874e-08
# Epoch 526/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6764e-07 - val_loss: 6.1686e-07
# Epoch 527/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.2670e-07 - val_loss: 3.8507e-08
# Epoch 528/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.4128e-07 - val_loss: 4.8824e-07
# Epoch 529/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.6272e-07 - val_loss: 8.0394e-08
# Epoch 530/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.4903e-07 - val_loss: 4.9131e-08
# Epoch 531/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.2493e-07 - val_loss: 3.0191e-08
# Epoch 532/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.5402e-07 - val_loss: 9.1907e-08
# Epoch 533/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 3.0339e-07 - val_loss: 6.9755e-07
# Epoch 534/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.2673e-07 - val_loss: 5.4690e-06
# Epoch 535/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.7194e-07 - val_loss: 8.2118e-08
# Epoch 536/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.5840e-07 - val_loss: 2.9383e-08
# Epoch 537/10000
# 4102/4102 [==============================] - 11s 3ms/step - loss: 2.1851e-07 - val_loss: 6.3883e-07
# Time:  5865.249428199997

# %%
score = model4.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 15625/15625 [==============================] - 15s 972us/step - loss: 2.5960e-04
#
# Test loss: 0.00025959915365092456

# %%
xy_valid, z_valid = prediction_NN(3000000,1000000, xy_2ECut_2, M_2ECut_2, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model4.predict(xy_valid)
stop = timeit.default_timer()
prediction_time4 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE2Cutpredictedsecond1.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  22.986619500001325

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_4 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_4), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE2Cuthistosecond1.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E2Cut - 346)/10

# %%
err_map_4 = array_for_error_map_1 (val_ang, val_en, angle_cut1, 346, xy_valid, err_4, 10)

# %%
ang4 = []
En4 = []
for i in range(10):
    ang4.append(round(angle_cut1 + (i+1)*val_ang,2))
    En4.append(round(346+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_4),xticklabels = ang4, yticklabels = En4)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapsecond1.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time4)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time4)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 5865.249428199997
# Tempo di predizione della rete di 1000000 elementi: 26.03288550000434

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 1000000 elementi con MadGraph: 14.287322861839217

# %%
n_min4 = round(training_time4/(t/len(M)-prediction_time4/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min4)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -499358746

# %%
err_1
# Out:
# array([0.09290817, 0.0244733 , 0.01901172, ..., 0.06901718, 0.12434866,
#        0.01464656])
