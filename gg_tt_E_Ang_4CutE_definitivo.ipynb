# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math
import timeit
import seaborn as sns

# %%
theta = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Angles.txt", delimiter=" ", unpack='true')

E = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Energy.txt", delimiter=" ", unpack='true')

M = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/MatrElem.txt", delimiter=" ", unpack='true')

t = np.loadtxt("C:/Users/User/Desktop/emanuele/installed/MG5_aMC_v3_3_1/PROC_SA_sm_5/SubProcesses/P1_gg_ttx/Time.txt", delimiter=" ", unpack='true')


max(theta)
# Out:
# 3.1411891489542554

# %%
angle_cut1 = 10./180.* math.pi
angle_cut2 = 170./180.*math.pi
Ecut = 0

# %%
ind = []
dim = M.size
for i in range(dim):
    if E[i] < 0 or theta[i] < angle_cut1 or theta[i] > angle_cut2:
        ind.append(i)
    if i%10000 == 0:
        print(i/10000, "/",dim/10000)
# Out:
# 0.0 / 1000.0
# 1.0 / 1000.0
# 2.0 / 1000.0
# 3.0 / 1000.0
# 4.0 / 1000.0
# 5.0 / 1000.0
# 6.0 / 1000.0
# 7.0 / 1000.0
# 8.0 / 1000.0
# 9.0 / 1000.0
# 10.0 / 1000.0
# 11.0 / 1000.0
# 12.0 / 1000.0
# 13.0 / 1000.0
# 14.0 / 1000.0
# 15.0 / 1000.0
# 16.0 / 1000.0
# 17.0 / 1000.0
# 18.0 / 1000.0
# 19.0 / 1000.0
# 20.0 / 1000.0
# 21.0 / 1000.0
# 22.0 / 1000.0
# 23.0 / 1000.0
# 24.0 / 1000.0
# 25.0 / 1000.0
# 26.0 / 1000.0
# 27.0 / 1000.0
# 28.0 / 1000.0
# 29.0 / 1000.0
# 30.0 / 1000.0
# 31.0 / 1000.0
# 32.0 / 1000.0
# 33.0 / 1000.0
# 34.0 / 1000.0
# 35.0 / 1000.0
# 36.0 / 1000.0
# 37.0 / 1000.0
# 38.0 / 1000.0
# 39.0 / 1000.0
# 40.0 / 1000.0
# 41.0 / 1000.0
# 42.0 / 1000.0
# 43.0 / 1000.0
# 44.0 / 1000.0
# 45.0 / 1000.0
# 46.0 / 1000.0
# 47.0 / 1000.0
# 48.0 / 1000.0
# 49.0 / 1000.0
# 50.0 / 1000.0
# 51.0 / 1000.0
# 52.0 / 1000.0
# 53.0 / 1000.0
# 54.0 / 1000.0
# 55.0 / 1000.0
# 56.0 / 1000.0
# 57.0 / 1000.0
# 58.0 / 1000.0
# 59.0 / 1000.0
# 60.0 / 1000.0
# 61.0 / 1000.0
# 62.0 / 1000.0
# ...

# %%
len(ind)
# Out:
# 152249

# %%
theta = np.delete(theta,ind)
E = np.delete(E,ind)
M = np.delete(M,ind)

# %%
xy = np.matrix([theta,E])
xy = xy.T
xy = xy.A
xy = xy.reshape(len(E),2)
print(xy.shape,type(xy))
# Out:
# (9847751, 2) <class 'numpy.ndarray'>

# %% [markdown]
# ## Grafico dati

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy[:50000,0], xy[:50000,1], M[:50000], label='Training', alpha=0.35)
ax.set_xlabel('$X$', fontsize=15)
ax.set_ylabel('$Y$', fontsize=15)
ax.set_zlabel('F(x,y)', fontsize=15)
#ax.view_init(10,20)
plt.show()

# %% [markdown]
# ## Grafico dei dati divisi in 4 strisce di energia

# %%
E4Cut_1 = 346 + (3000 - 346)/4 
E4Cut_2 = (3000 + 346)/2
E4Cut_3 = 346 + (3000 - 346)/4*3

M_4ECut_1 = []
theta_4ECut_1 = []
E_4ECut_1 = []

M_4ECut_2 = []
theta_4ECut_2 = []
E_4ECut_2 = []

M_4ECut_3 = []
theta_4ECut_3 = []
E_4ECut_3 = []

M_4ECut_4 = []
theta_4ECut_4 = []
E_4ECut_4 = []

for i in range(len(M)):
    if E[i] < E4Cut_1:
        theta_4ECut_1.append(theta[i])
        E_4ECut_1.append(E[i])
        M_4ECut_1.append(M[i])
    elif E[i] >= E4Cut_1 and E[i] < E4Cut_2 :
        theta_4ECut_2.append(theta[i])
        E_4ECut_2.append(E[i])
        M_4ECut_2.append(M[i])
    elif E[i] >= E4Cut_2 and E[i] < E4Cut_3 :
        theta_4ECut_3.append(theta[i])
        E_4ECut_3.append(E[i])
        M_4ECut_3.append(M[i])
    elif E[i] >= E4Cut_3 :
        theta_4ECut_4.append(theta[i])
        E_4ECut_4.append(E[i])
        M_4ECut_4.append(M[i])

# %% [markdown]
# ### Grafico con energia [346,1011] Gev

# %%
M_4ECut_1 = np.array(M_4ECut_1)
theta_4ECut_1 = np.array(theta_4ECut_1)
E_4ECut_1 = np.array(E_4ECut_1)

# %%
xy_4ECut_1 = np.matrix([theta_4ECut_1,E_4ECut_1])
xy_4ECut_1 = xy_4ECut_1.T
xy_4ECut_1 = xy_4ECut_1.A
xy_4ECut_1 = xy_4ECut_1.reshape(len(E_4ECut_1),2)
print(xy_4ECut_1.shape,type(xy_4ECut_1))
# Out:
# (2462461, 2) <class 'numpy.ndarray'>

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_4ECut_1[:50000,0], xy_4ECut_1[:50000,1], M_4ECut_1[:50000], 
           label='Training', alpha=0.35)
ax.set_xlabel('$X$', fontsize=15)
ax.set_ylabel('$Y$', fontsize=15)
ax.set_zlabel('F(x,y)', fontsize=15)
#ax.view_init(10,20)
plt.show()

# %% [markdown]
# ### Grafico con energia [1011,1674] Gev

# %%
M_4ECut_2 = np.array(M_4ECut_2)
theta_4ECut_2 = np.array(theta_4ECut_2)
E_4ECut_2 = np.array(E_4ECut_2)

# %%
xy_4ECut_2 = np.matrix([theta_4ECut_2,E_4ECut_2])
xy_4ECut_2 = xy_4ECut_2.T
xy_4ECut_2 = xy_4ECut_2.A
xy_4ECut_2 = xy_4ECut_2.reshape(len(E_4ECut_2),2)
print(xy_4ECut_2.shape,type(xy_4ECut_2))
# Out:
# (2461756, 2) <class 'numpy.ndarray'>

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_4ECut_2[:50000,0], xy_4ECut_2[:50000,1], M_4ECut_2[:50000], 
           label='Training', alpha=0.35)
ax.set_xlabel('$X$', fontsize=15)
ax.set_ylabel('$Y$', fontsize=15)
ax.set_zlabel('F(x,y)', fontsize=15)
#ax.view_init(10,20)
plt.show()

# %% [markdown]
# ### Grafico con energia [1674,2337] Gev

# %%
M_4ECut_3 = np.array(M_4ECut_3)
theta_4ECut_3 = np.array(theta_4ECut_3)
E_4ECut_3 = np.array(E_4ECut_3)

# %%
xy_4ECut_3 = np.matrix([theta_4ECut_3,E_4ECut_3])
xy_4ECut_3 = xy_4ECut_3.T
xy_4ECut_3 = xy_4ECut_3.A
xy_4ECut_3 = xy_4ECut_3.reshape(len(E_4ECut_3),2)
print(xy_4ECut_3.shape,type(xy_4ECut_3))
# Out:
# (2465166, 2) <class 'numpy.ndarray'>

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_4ECut_3[:50000,0], xy_4ECut_3[:50000,1], M_4ECut_3[:50000], 
           label='Training', alpha=0.35)
ax.set_xlabel('$X$', fontsize=15)
ax.set_ylabel('$Y$', fontsize=15)
ax.set_zlabel('F(x,y)', fontsize=15)
#ax.view_init(10,20)
plt.show()

# %% [markdown]
# ### Grafico con energia [2337,3000] Gev

# %%
M_4ECut_4 = np.array(M_4ECut_4)
theta_4ECut_4 = np.array(theta_4ECut_4)
E_4ECut_4 = np.array(E_4ECut_4)

# %%
xy_4ECut_4 = np.matrix([theta_4ECut_4,E_4ECut_4])
xy_4ECut_4 = xy_4ECut_4.T
xy_4ECut_4 = xy_4ECut_4.A
xy_4ECut_4 = xy_4ECut_4.reshape(len(E_4ECut_4),2)
print(xy_4ECut_4.shape,type(xy_4ECut_4))
# Out:
# (2458368, 2) <class 'numpy.ndarray'>

# %%
fig = plt.figure(figsize=(6,6))
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Training data", fontsize=15)
ax.scatter(xy_4ECut_4[:50000,0], xy_4ECut_4[:50000,1], M_4ECut_4[:50000], 
           label='Training', alpha=0.35)
ax.set_xlabel('$X$', fontsize=15)
ax.set_ylabel('$Y$', fontsize=15)
ax.set_zlabel('F(x,y)', fontsize=15)
#ax.view_init(10,20)
plt.show()

# %% [markdown]
# # Reti Neurali
# ## Preparazione

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras import optimizers, losses, metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras import activations
from tensorflow.keras.callbacks import EarlyStopping

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from numpy import mean
from numpy import std

# %%
def baseline_model_dataset(layers, lr=0.001, activation='relu', loss='mean_squared_error'):
        'define and compile model with fixing weight initialisers and a random dataset'
        # create model
        # at some point can use new Keras tuning feature for optimising this model

        
        model = Sequential()
        model.add(Dense(10, input_shape=(2,),activation='relu'))
        model.add(Dense(layers[0], input_dim=(2))) #dim può essere anche "2", non lo so
        if activation == 'tanh':
            model.add(Activation(activations.tanh))
        elif activation == 'relu':
            model.add(Activation(activations.relu))
        else:
            raise ValueError('activation supported are either tanh or relu, you have used {}'.format(activation))

        for i in range(1,len(layers)):
            model.add(Dense(layers[i]))
            if activation == 'tanh':
                model.add(Activation(activations.tanh))
            elif activation == 'relu':
                model.add(Activation(activations.relu))

        model.add(Dense(1))
        # Compile model
        model.compile(optimizer = Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = loss)
        
        return model

# %%
def baseline_model(layers, lr=0.001, activation='tanh', loss='mean_squared_error'):
        'define and compile model with a fixed dataset but random weights'
        # create model
        # at some point can use new Keras tuning feature for optimising this model
        model = Sequential()
        model.add(Dense(layers[0], input_dim=(2)))
        if activation == 'tanh':
            model.add(Activation(activations.tanh))
        elif activation == 'relu':
            model.add(Activation(activations.relu))
        else:
            raise ValueError('activation supported are either tanh or relu, you have used {}'.format(activation))
        
        for i in range(1, len(layers)):
            model.add(Dense(layers[i]))
            if activation == 'tanh':
                model.add(Activation(activations.tanh))
            elif activation == 'relu':
                model.add(Activation(activations.relu))

        model.add(Dense(1))
        # Compile model
        model.compile(optimizer = Adam(learning_rate=lr, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = loss)
        
        return model

# %%
def get_dataset(xy, M, input_scaler, output_scaler, interval):
	# generate dataset
	#X, y = make_regression(n_samples=1000, n_features=20, noise=0.1, random_state=1)
	# split into train and test
	#n_train = 500
    n_train = int(interval / 100 * 70)
    n_valid = int(interval / 100 * 30)
    print ("# training points :",n_train,"\n# validation points: ", n_valid)
    trainX, testX = xy[:n_train], xy[n_train:n_train + n_valid]
    trainy, testy = M[:n_train], M[n_train:n_train + n_valid]
	# scale inputs
    if input_scaler is not None:
        # fit scaler
        input_scaler.fit(trainX)
        # transform training dataset
        trainX = input_scaler.transform(trainX)
        # transform test dataset
        testX = input_scaler.transform(testX)
    if output_scaler is not None:
        # reshape 1d arrays to 2d arrays
        trainy = trainy.reshape(len(trainy), 1)
        testy = testy.reshape(len(testy), 1)
        # fit scaler on training dataset
        output_scaler.fit(trainy)
        # transform training dataset
        trainy = output_scaler.transform(trainy)
        # transform test dataset
        testy = output_scaler.transform(testy)
    return trainX, trainy, testX, testy, output_scaler, input_scaler

# %%
def prediction_NN(begin ,dim, xy, M, scaler_output, scaler_input):
    xy_valid = xy[begin:begin+dim]
    scaler_input.fit(xy_valid)
    #transform training dataset
    xy_valid = scaler_input.transform(xy_valid)
    #transform test dataset

    z_valid = M[begin:begin+dim]
    z_valid = z_valid.reshape(len(z_valid), 1)
    #fit scaler on training dataset
    scaler_output.fit(z_valid)
    # transform training dataset
    z_valid = scaler_output.transform(z_valid)
    # transform test dataset
    
    return xy_valid, z_valid

# %%
def rescale(xy_valid, z_predicted, z_valid, scaler_input, scaler_output):
    xy_valid = scaler_input.inverse_transform(xy_valid)
    z_predicted = scaler_output.inverse_transform(z_predicted)
    z_predicted = z_predicted.reshape(len(z_predicted),)
    z_valid = scaler_output.inverse_transform(z_valid)
    z_valid = z_valid.reshape(len(z_valid),)
    return xy_valid, z_predicted, z_valid

# %%
def relative_error(z_predicted, z_valid):
    err = abs(np.diff([z_predicted,z_valid],axis=0))
    err = err.reshape(len(z_predicted),)
    err = np.divide(err,z_valid)
    return err

# %%
def array_for_error_map (val_ang, val_en, cut_value, xy_valid, err, gg, dim):
    err_map = np.zeros((dim, dim))
    err_counter = np.zeros((dim,dim))

    if gg == 'ang':
        for i in range(len(xy_valid)):
            for j in range(dim):
                for k in range(dim):
                    if xy_valid[i,0] > cut_value + val_ang*(k) and xy_valid[i,0] < cut_value + val_ang*(k+1) and xy_valid[i,1] > 346 + val_en*j and xy_valid[i,1] < 346 + val_en*(j+1):
                        err_map[j,k] += err[i]
                        #print(err_map[k,j])
                        err_counter[k,j] += 1
    elif gg == 'en':
        for i in range(len(xy_valid)):
            for j in range(dim):
                for k in range(dim):
                    if xy_valid[i,0] > val_ang*(k) and xy_valid[i,0] < val_ang*(k+1) and xy_valid[i,1] > cut_value + val_en*j and xy_valid[i,1] < cut_value + val_en*(j+1):
                        err_map[k,j] += err[i]
                        #print(err_map[k,j])
                        err_counter[k,j] += 1
    else:
        raise ValueError('You can pick ang or en, you have used {}'.format(gg))
        
        
                    
    for j in range(dim):
        for k in range(dim):
            err_map[k,j] /= err_counter[k,j]
            
    return err_map

# %%
def array_for_error_map_1 (val_ang, val_en, cut_value_ang, cut_value_en, xy_valid, err, dim):
    err_map = np.zeros((dim, dim))
    err_counter = np.zeros((dim,dim))

    for i in range(len(xy_valid)):
        for j in range(dim):
            for k in range(dim):
                if xy_valid[i,0] > cut_value_ang + val_ang*(k) and xy_valid[i,0] < cut_value_ang + val_ang*(k+1) and xy_valid[i,1] > cut_value_en + val_en*j and xy_valid[i,1] < cut_value_en + val_en*(j+1):
                    err_map[j,k] += err[i]
                    #print(err_map[k,j])
                    err_counter[k,j] += 1
                            
    for j in range(dim):
        for k in range(dim):
            err_map[k,j] /= err_counter[k,j]
            
    return err_map

# %% [markdown]
# # Rete Neurale #1

# %% [markdown]
# Prima striscia

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_1, M_4ECut_1, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model1 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# activation (Activation)      (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                840
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                820
# _________________________________________________________________
# activation_2 (Activation)    (None, 20)                0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model1.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time1 = stop - start
print('Time: ', training_time1)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 7s 2ms/step - loss: 0.0032 - val_loss: 7.6882e-04
# Epoch 2/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 6.4850e-04 - val_loss: 5.3568e-04
# Epoch 3/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.7546e-04 - val_loss: 2.6792e-04
# Epoch 4/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.7591e-04 - val_loss: 1.1346e-04
# Epoch 5/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.1268e-04 - val_loss: 1.3599e-04
# Epoch 6/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 7.7138e-05 - val_loss: 1.5380e-04
# Epoch 7/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 5.0133e-05 - val_loss: 2.9537e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.7650e-05 - val_loss: 3.3994e-05
# Epoch 9/10000
# ...

# %%
score = model1.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 30s 2ms/step - loss: 1.0668e-08
#
# Test loss: 1.0667830174782011e-08

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_1, M_4ECut_1, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model1.predict(xy_valid)
stop = timeit.default_timer()
prediction_time1 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedfirst1.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_1 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_1), n_bins, range=(0,5))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistofirst1.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_1 = array_for_error_map_1 (val_ang, val_en, angle_cut1, 346, xy_valid, err_1, 10)

# %%
ang1 = []
En1 = []
for i in range(10):
    ang1.append(round(angle_cut1 + (i+1)*val_ang,2))
    En1.append(round(346+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_1),xticklabels = ang1, yticklabels = En1)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapfirst.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time1)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time1)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 4106.7878321
# Tempo di predizione della rete di 462461 elementi: 10.12921069999993

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 462461 elementi con MadGraph: 6.607329618009026

# %%
n_min1 = round(training_time1/(t/len(M)-prediction_time1/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min1)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -539265570

# %%
err_1
# Out:
# array([0.00270503, 0.00562681, 0.00452308, ..., 0.00744007, 0.00478092,
#        0.00683796])

# %% [markdown]
# # Rete Neurale #2

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_1, M_4ECut_1, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model2 = tf.keras.Sequential()
model2.add(Dense(15, input_shape=(2,),activation='relu'))
model2.add(Dense(40, input_shape=(2,),activation='tanh'))
model2.add(Dense(45, input_shape=(2,),activation='tanh'))
model2.add(Dense(30, input_shape=(2,),activation='tanh'))
model2.add(Dense(15, input_shape=(2,),activation='relu'))
model2.add(Dense(1))
model2.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 15)                45
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                640
# _________________________________________________________________
# dense_7 (Dense)              (None, 45)                1845
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                1380
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 16
# ...
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model2.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time2 = stop - start
print('Time: ', training_time2)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 5.7533e-04 - val_loss: 5.1611e-05
# Epoch 2/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 4.7343e-05 - val_loss: 3.1722e-05
# Epoch 3/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 3.4853e-05 - val_loss: 1.1060e-04
# Epoch 4/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.9216e-05 - val_loss: 2.1817e-05
# Epoch 5/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.4113e-05 - val_loss: 2.0451e-05
# Epoch 6/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.0007e-05 - val_loss: 1.2838e-05
# Epoch 7/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.7858e-05 - val_loss: 1.5456e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.6570e-05 - val_loss: 1.3140e-05
# Epoch 9/10000
# ...

# %%
score = model2.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 32s 2ms/step - loss: 2.4566e-08
#
# Test loss: 2.456631875702442e-08

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_1, M_4ECut_1, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model2.predict(xy_valid)
stop = timeit.default_timer()
prediction_time2 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedsecond1.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_2 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_2), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistosecond1.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_2 = array_for_error_map_1 (val_ang, val_en, angle_cut1, 346, xy_valid, err_2, 10)

# %%
ang2 = []
En2 = []
for i in range(10):
    ang2.append(round(angle_cut1 + (i+1)*val_ang,2))
    En2.append(round(346+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_2),xticklabels = ang2, yticklabels = En2)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE4Cutmapsecond1.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time2)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time2)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 3641.9367512999997
# Tempo di predizione della rete di 462461 elementi: 11.330064900000252

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 462461 elementi con MadGraph: 6.607329618009026

# %%
n_min2 = round(training_time2/(t/len(M)-prediction_time2/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min2)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -356626745

# %%
err_1
# Out:
# array([0.00270503, 0.00562681, 0.00452308, ..., 0.00744007, 0.00478092,
#        0.00683796])

# %% [markdown]
# # Rete Neurale #3

# %% [markdown]
# Seconda parte

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_2, M_4ECut_2, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model3 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                220
# _________________________________________________________________
# activation_3 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 40)                840
# _________________________________________________________________
# activation_4 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                820
# _________________________________________________________________
# activation_5 (Activation)    (None, 20)                0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model3.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time3 = stop - start
print('Time: ', training_time3)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 7s 2ms/step - loss: 0.0022 - val_loss: 4.0269e-04
# Epoch 2/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.3456e-04 - val_loss: 2.9460e-04
# Epoch 3/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.1786e-04 - val_loss: 3.7211e-04
# Epoch 4/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.0224e-04 - val_loss: 2.6334e-04
# Epoch 5/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 2.7126e-04 - val_loss: 2.1411e-04
# Epoch 6/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.9910e-04 - val_loss: 2.2322e-04
# Epoch 7/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.2143e-04 - val_loss: 7.2724e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 8.0706e-05 - val_loss: 6.0313e-05
# Epoch 9/10000
# ...

# %%
score = model3.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 30s 2ms/step - loss: 7.1769e-09
#
# Test loss: 7.176868876968001e-09

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_2, M_4ECut_2, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model3.predict(xy_valid)
stop = timeit.default_timer()
prediction_time3 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedfirst2.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_3 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_3), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistofirst2.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_3 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_1, xy_valid, err_3, 10)

# %%
ang3 = []
En3 = []
for i in range(10):
    ang3.append(round(angle_cut1 + (i+1)*val_ang,2))
    En3.append(round(E4Cut_1+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_3),xticklabels = ang3, yticklabels = En3)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE4Cutmapfirst2.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time3)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time3)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 2185.3812737999997
# Tempo di predizione della rete di 461756 elementi: 10.017993800000113

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 461756 elementi con MadGraph: 6.597257055391429

# %%
n_min3 = round(training_time3/(t/len(M)-prediction_time3/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min3)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -294998707

# %% [markdown]
# # Rete Neurale #4

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_2, M_4ECut_2, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model4 = tf.keras.Sequential()
model4.add(Dense(15, input_shape=(2,),activation='relu'))
model4.add(Dense(40, input_shape=(2,),activation='tanh'))
model4.add(Dense(45, input_shape=(2,),activation='tanh'))
model4.add(Dense(30, input_shape=(2,),activation='tanh'))
model4.add(Dense(15, input_shape=(2,),activation='relu'))
model4.add(Dense(1))
model4.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_17 (Dense)             (None, 40)                640
# _________________________________________________________________
# dense_18 (Dense)             (None, 45)                1845
# _________________________________________________________________
# dense_19 (Dense)             (None, 30)                1380
# _________________________________________________________________
# dense_20 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 16
# ...
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model4.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time4 = stop - start
print('Time: ', training_time4)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 3.6712e-04 - val_loss: 5.8754e-05
# Epoch 2/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.8455e-05 - val_loss: 2.9033e-05
# Epoch 3/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.2162e-05 - val_loss: 1.3622e-05
# Epoch 4/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.0648e-05 - val_loss: 1.2647e-05
# Epoch 5/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.7074e-05 - val_loss: 2.2125e-05
# Epoch 6/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.0175e-05 - val_loss: 1.0592e-05
# Epoch 7/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.5807e-05 - val_loss: 4.0835e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.4579e-05 - val_loss: 2.2055e-05
# Epoch 9/10000
# ...

# %%
score = model4.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 32s 2ms/step - loss: 2.7988e-08
#
# Test loss: 2.7988038553417027e-08

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_2, M_4ECut_2, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model4.predict(xy_valid)
stop = timeit.default_timer()
prediction_time4 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedsecond2.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_4 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_4), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistosecond2.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_4 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_1, xy_valid, err_4, 10)

# %%
ang4 = []
En4 = []
for i in range(10):
    ang4.append(round(angle_cut1 + (i+1)*val_ang,2))
    En4.append(round(E4Cut_1+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_4),xticklabels = ang4, yticklabels = En4)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapsecond2.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time4)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time4)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 2702.0772445000002
# Tempo di predizione della rete di 461756 elementi: 11.034612700001162

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 461756 elementi con MadGraph: 6.597257055391429

# %%
n_min4 = round(training_time4/(t/len(M)-prediction_time4/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min4)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -281181064

# %% [markdown]
# # Rete Neurale #5

# %% [markdown]
# Prima striscia

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_3, M_4ECut_3, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model5 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_22 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                220
# _________________________________________________________________
# activation_6 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 40)                840
# _________________________________________________________________
# activation_7 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 20)                820
# _________________________________________________________________
# activation_8 (Activation)    (None, 20)                0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model5.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time5 = stop - start
print('Time: ', training_time5)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 7s 2ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 2/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 3/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 0.0013 - val_loss: 9.2887e-04
# Epoch 4/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 5.5201e-04 - val_loss: 2.8906e-04
# Epoch 5/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 2.6917e-04 - val_loss: 1.3219e-04
# Epoch 6/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.5673e-04 - val_loss: 8.3888e-05
# Epoch 7/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.0606e-04 - val_loss: 1.2142e-04
# Epoch 8/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 7.6932e-05 - val_loss: 3.0585e-05
# Epoch 9/10000
# ...

# %%
score = model5.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 30s 2ms/step - loss: 1.0280e-08
#
# Test loss: 1.0279639361954196e-08

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_3, M_4ECut_3, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model1.predict(xy_valid)
stop = timeit.default_timer()
prediction_time5 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time5)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedfirst3.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.035090899998977

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_5 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_5), n_bins, range=(0,5))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistofirst3.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_5 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_2, xy_valid, err_5, 10)

# %%
ang5 = []
En5 = []
for i in range(10):
    ang5.append(round(angle_cut1 + (i+1)*val_ang,2))
    En5.append(round(E4Cut_2+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_5),xticklabels = ang5, yticklabels = En5)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapfirst.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time5)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time5)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 2428.477153399999
# Tempo di predizione della rete di 465166 elementi: 10.035090899998977

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 465166 elementi con MadGraph: 6.645976826350301

# %%
n_min5 = round(training_time5/(t/len(M)-prediction_time5/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min5)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -333315722

# %% [markdown]
# # Rete Neurale #6

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_3, M_4ECut_3, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model6 = tf.keras.Sequential()
model6.add(Dense(15, input_shape=(2,),activation='relu'))
model6.add(Dense(40, input_shape=(2,),activation='tanh'))
model6.add(Dense(45, input_shape=(2,),activation='tanh'))
model6.add(Dense(30, input_shape=(2,),activation='tanh'))
model6.add(Dense(15, input_shape=(2,),activation='relu'))
model6.add(Dense(1))
model6.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_27 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_28 (Dense)             (None, 40)                640
# _________________________________________________________________
# dense_29 (Dense)             (None, 45)                1845
# _________________________________________________________________
# dense_30 (Dense)             (None, 30)                1380
# _________________________________________________________________
# dense_31 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 16
# ...
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model6.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time6 = stop - start
print('Time: ', training_time6)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 0.0017 - val_loss: 2.4084e-04
# Epoch 2/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.9913e-04 - val_loss: 7.7495e-05
# Epoch 3/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 1.1701e-04 - val_loss: 6.0792e-05
# Epoch 4/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 9.6564e-05 - val_loss: 7.0327e-05
# Epoch 5/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 8.4091e-05 - val_loss: 4.7736e-05
# Epoch 6/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 7.5092e-05 - val_loss: 5.3670e-05
# Epoch 7/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 6.8817e-05 - val_loss: 4.1153e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 6.3484e-05 - val_loss: 4.9416e-05
# Epoch 9/10000
# ...

# %%
score = model6.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 31s 2ms/step - loss: 2.3759e-08
#
# Test loss: 2.3758602196721768e-08

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_3, M_4ECut_3, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model6.predict(xy_valid)
stop = timeit.default_timer()
prediction_time6 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedsecond3.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_6 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_6), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistosecond3.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_6 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_2, xy_valid, err_6, 10)

# %%
ang6 = []
En6 = []
for i in range(10):
    ang6.append(round(angle_cut1 + (i+1)*val_ang,2))
    En6.append(round(E4Cut_2+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_6),xticklabels = ang6, yticklabels = En6)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE4Cutmapsecond3.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time6)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time6)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 3141.085347799999
# Tempo di predizione della rete di 465166 elementi: 10.90117139999711

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 465166 elementi con MadGraph: 6.645976826350301

# %%
n_min6 = round(training_time6/(t/len(M)-prediction_time6/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min6)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -343374687

# %% [markdown]
# # Rete Neurale #7

# %% [markdown]
# Seconda parte

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_4, M_4ECut_4, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)
layers = [20,40,20]
model7 = baseline_model_dataset(layers, lr=0.001, activation='tanh', loss='mean_squared_error')
# compile the model choosing optimizer, loss and metrics objects
#model7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model7.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_34 (Dense)             (None, 20)                220
# _________________________________________________________________
# activation_9 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 40)                840
# _________________________________________________________________
# activation_10 (Activation)   (None, 40)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 20)                820
# _________________________________________________________________
# activation_11 (Activation)   (None, 20)                0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model7.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time7 = stop - start
print('Time: ', training_time7)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 7s 2ms/step - loss: 0.0013 - val_loss: 3.9026e-04
# Epoch 2/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 4.1414e-04 - val_loss: 3.6783e-04
# Epoch 3/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 4.0236e-04 - val_loss: 3.6049e-04
# Epoch 4/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.8287e-04 - val_loss: 3.8576e-04
# Epoch 5/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 3.0165e-04 - val_loss: 2.5111e-04
# Epoch 6/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 2.4422e-04 - val_loss: 1.6648e-04
# Epoch 7/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 1.1440e-04 - val_loss: 6.3787e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 6s 2ms/step - loss: 6.0069e-05 - val_loss: 5.5735e-05
# Epoch 9/10000
# ...

# %%
score = model7.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 30s 2ms/step - loss: 6.0502e-09
#
# Test loss: 6.050208778418664e-09

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_4, M_4ECut_4, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model7.predict(xy_valid)
stop = timeit.default_timer()
prediction_time7 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedfirst4.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_7 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_6), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistofirst4.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_7 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_3, xy_valid, err_7, 10)

# %%
ang7 = []
En7 = []
for i in range(10):
    ang7.append(round(angle_cut1 + (i+1)*val_ang,2))
    En7.append(round(E4Cut_3+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_7),xticklabels = ang7, yticklabels = En7)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE4Cutmapfirst4.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time7)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time7)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 2697.2512645000024
# Tempo di predizione della rete di 458368 elementi: 10.31056759999774

# %%
t_1 = t/len(M)
t_regression1 = t_1*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 458368 elementi con MadGraph: 6.548851605535518

# %%
n_min7 = round(training_time7/(t/len(M)-prediction_time7/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min7)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -328662150

# %% [markdown]
# # Rete Neurale #8

# %%
xy_train, z_train, xy_valid, z_valid, scaler_out, scaler_in = get_dataset(xy_4ECut_4, M_4ECut_4, MinMaxScaler(), MinMaxScaler(),2000000)
# Out:
# # training points : 1400000
# # validation points:  600000

# %% [markdown]
# ### Modello

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, 
                   verbose=0, restore_best_weights=True)

model8 = tf.keras.Sequential()
model8.add(Dense(15, input_shape=(2,),activation='relu'))
model8.add(Dense(40, input_shape=(2,),activation='tanh'))
model8.add(Dense(45, input_shape=(2,),activation='tanh'))
model8.add(Dense(30, input_shape=(2,),activation='tanh'))
model8.add(Dense(15, input_shape=(2,),activation='relu'))
model8.add(Dense(1))
model8.compile(optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False), loss = 'mse')

# %%
model8.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_38 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_39 (Dense)             (None, 40)                640
# _________________________________________________________________
# dense_40 (Dense)             (None, 45)                1845
# _________________________________________________________________
# dense_41 (Dense)             (None, 30)                1380
# _________________________________________________________________
# dense_42 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 16
# ...
# Total params: 4,391
# Trainable params: 4,391
# Non-trainable params: 0
# ...

# %% [markdown]
# ### Fit e prestazioni

# %%
start = timeit.default_timer()

history = model8.fit(x=xy_train, y=z_train, 
          batch_size=512, epochs=10000,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(xy_valid, z_valid),
          callbacks=[ES])

stop = timeit.default_timer()
training_time8 = stop - start
print('Time: ', training_time8)
# Out:
# Epoch 1/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 4.9821e-04 - val_loss: 6.5669e-05
# Epoch 2/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 6.9067e-05 - val_loss: 6.8981e-05
# Epoch 3/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 5.0837e-05 - val_loss: 2.4382e-05
# Epoch 4/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 4.1993e-05 - val_loss: 1.5779e-05
# Epoch 5/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 3.5534e-05 - val_loss: 1.3218e-05
# Epoch 6/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 3.1760e-05 - val_loss: 3.2021e-05
# Epoch 7/10000
# 2735/2735 [==============================] - 8s 3ms/step - loss: 3.7650e-05 - val_loss: 2.4951e-05
# Epoch 8/10000
# 2735/2735 [==============================] - 7s 3ms/step - loss: 2.7954e-05 - val_loss: 1.2294e-05
# Epoch 9/10000
# ...

# %%
score = model8.evaluate(xy_valid, z_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score)
#print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 18750/18750 [==============================] - 33s 2ms/step - loss: 8.2637e-09
#
# Test loss: 8.263670636665665e-09

# %%
xy_valid, z_valid = prediction_NN(2000000,500000, xy_4ECut_4, M_4ECut_4, scaler_out ,scaler_in)

start = timeit.default_timer()
z_predicted = model8.predict(xy_valid)
stop = timeit.default_timer()
prediction_time8 = stop - start

init = 0
end = 50000
print ("Prediction time: ", prediction_time1)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel('F(x,y)')
ax.scatter(xy_valid[init:end,0],xy_valid[init:end,1], z_valid[init:end])
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_title("Predicted data on Target data")
ax1.scatter(xy_valid[init:end,0], xy_valid[init:end,1], z_predicted[init:end],c='red')
ax1.set_xlabel('$\~ \u03B8 $', fontsize=15)
ax1.set_ylabel('$\~ \u221A s$', fontsize=15)
ax1.set_zlabel('$\~ M$', fontsize=15)
#plt.ylim(1000)
#ax.view_init(45,35)
plt.savefig('C:/Users/User/Desktop/ggttE4Cutpredictedsecond4.png')
plt.grid(True); plt.show()
# Out:
# Prediction time:  10.12921069999993

# %% [markdown]
# ### Annullamento dello scaling

# %%
xy_valid, z_predicted, z_valid = rescale(xy_valid, z_predicted, z_valid, scaler_in, scaler_out)

# %%
err_8 = relative_error(z_predicted, z_valid)

# %% [markdown]
# ### Errori

# %%
n_bins = 25
n, bins, patches = plt.hist(-np.log10(err_8), n_bins, range=(0,6))

plt.xlabel('$- Log_{10}(Err^{relative})$')
plt.ylabel("Counts")
plt.title('Histogram of relative errors of network predictions')
plt.grid(True)
plt.savefig('C:/Users/User/Desktop/ggttE4Cuthistosecond4.png')
plt.show()

# %% [markdown]
# ### Mappa degli errori

# %%
val_ang = (math.pi - 2*angle_cut1)/10
val_en = (E4Cut_1 - 346)/10

# %%
err_map_8 = array_for_error_map_1 (val_ang, val_en, angle_cut1, E4Cut_3, xy_valid, err_8, 10)

# %%
ang8 = []
En8 = []
for i in range(10):
    ang8.append(round(angle_cut1 + (i+1)*val_ang,2))
    En8.append(round(E4Cut_3+(i+1)*val_en,))
    
ax = sns.heatmap(-np.log10(err_map_8),xticklabels = ang8, yticklabels = En8)
ax.set_title("Error Map. Scale: $- Log_{10}(Err^{relative})$", fontsize = 13)
ax.set_ylabel("Energia [Gev]")
ax.set_xlabel("Angle [rad]")
plt.savefig('C:/Users/User/Desktop/ggttE2Cutmapsecond4.png')
plt.show()

# %% [markdown]
# ### Analisi dei tempi
# Alcuni calcoli sono piuttosto imprecisi

# %%
print ("Tempo per la generazione di", len(M),"elementi con MadGraph:",t)
print ("Tempo di training della rete:", training_time8)
print ("Tempo di predizione della rete di",len(z_predicted),"elementi:", prediction_time8)
# Out:
# Tempo per la generazione di 9847751 elementi con MadGraph: 140.697998
# Tempo di training della rete: 5429.063391600001
# Tempo di predizione della rete di 458368 elementi: 11.010743399998319

# %%
t_2 = t/len(M)
t_regression1 = t_2*len(z_predicted)
print("Interpolazione del tempo di generazione di",len(z_predicted),"elementi con MadGraph:",t_regression1)
# Out:
# Interpolazione del tempo di generazione di 458368 elementi con MadGraph: 6.548851605535518

# %%
n_min8 = round(training_time8/(t/len(M)-prediction_time8/len(z_predicted)))

# %%
print("Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente:",n_min8)
# Out:
# Numero minimo necessario per riassorbire il tempo di predizione della rete e renderlo un metodo conveniente: -557725073
